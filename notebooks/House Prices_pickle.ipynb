000\n101.0,1962,1,139000\n105.0,2006,2,155000\n299.0,1990,3,320000\n135.0,2005,2,163990\n92.0,1969,2,180000\n104.0,1939,1,100000\n100.0,1958,1,136000\n111.0,1993,2,153900\n147.0,1979,2,181000\n70.0,1935,0,84500\n89.0,1976,2,128000\n78.0,1930,0,87000\n125.0,1966,2,155000\n98.0,1958,2,150000\n200.0,1966,2,226000\n191.0,2000,2,244000\n123.0,1959,2,150750\n120.0,2001,2,220000\n160.0,1968,2,180000\n156.0,1970,2,174000\n113.0,1967,1,143000\n182.0,1988,3,171000\n172.0,1999,3,230000\n164.0,1997,2,231500\n80.0,1971,0,115000\n161.0,2005,2,260000\n129.0,1952,2,166000\n139.0,1999,2,204000\n161.0,1963,2,125000\n159.0,2004,2,130000\n81.0,1931,1,105000\n189.0,2001,2,222500\n100.0,2004,0,141000\n125.0,1936,1,115000\n90.0,1975,2,122000\n159.0,2007,3,372402\n185.0,1971,2,190000\n116.0,1960,2,235000\n111.0,1923,1,125000\n102.0,1924,0,79000\n97.0,1950,2,109500\n183.0,2009,3,269500\n181.0,2004,2,254900\n229.0,2005,2,320000\n114.0,1984,2,162500\n248.0,2003,3,412500\n143.0,2005,2,220000\n82.0,1956,0,103200\n150.0,1926,1,152000\n126.0,1940,0,127500\n173.0,1955,1,190000\n201.0,2007,3,325624\n160.0,2004,2,183500\n159.0,1981,2,228000\n128.0,1941,2,128500\n154.0,1960,2,215000\n164.0,1987,2,239000\n127.0,1961,2,163000\n153.0,1986,2,184000\n200.0,1950,2,243000\n191.0,1988,2,211000\n178.0,1958,2,172500\n208.0,2008,3,501837\n90.0,1923,2,100000\n142.0,2000,2,177000\n167.0,1920,1,200100\n124.0,1957,1,120000\n193.0,2003,2,200000\n116.0,1908,2,127000\n335.0,1892,3,475000\n113.0,1990,2,173000\n154.0,1916,1,135000\n114.0,1979,2,153337\n148.0,2001,2,286000\n253.0,1932,2,3150 ...

# %%
import io
import pandas as pd

df = pd.read_csv(io.BytesIO(uploaded['casas.csv']))
df.head()
# Out:
#    tamanho   ano  garagem   preco
# 0    159.0  2003        2  208500
# 1    117.0  1976        2  181500
# 2    166.0  2001        2  223500
# 3    160.0  1915        3  140000
# 4    204.0  2000        3  250000

# %%
colunas = ['tamanho', 'ano', 'garagem']

# %%
X = df.drop('preco', axis=1)
X.head()
# Out:
#    tamanho   ano  garagem
# 0    159.0  2003        2
# 1    117.0  1976        2
# 2    166.0  2001        2
# 3    160.0  1915        3
# 4    204.0  2000        3

# %%
y = df['preco']
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: preco, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()

# importante : as linhas ao lado esquerdo dos valores do tamanho são escolhidas aleatoriamente !
# Out:
#       tamanho   ano  garagem
# 135     156.0  1970        2
# 1452    100.0  2005        2
# 762     144.0  2009        2
# 932     177.0  2006        3
# 435     154.0  1996        2

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Salvando o modelo :
import pickle

# %%
pickle.dump(modelo, open('modelo.sav', 'wb'))

# %%
files.download('modelo.sav')

# %%
import sklearn
sklearn.__version__
# Out:
# '0.22.2.post1'
